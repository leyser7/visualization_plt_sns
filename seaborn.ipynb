# %%
# !pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (1.3.3)
# Requirement already satisfied: seaborn in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in c:\users\ccalzate\downloads\visualization\venv\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %% [markdown]
# Seaborn

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.11.2

# %%
sns.set()

plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], alpha=0.5)

# %% [markdown]
# # Charts Types

# %% [markdown]
# <img src=https://seaborn.pydata.org/_images/function_overview_8_0.png>

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.histplot(data=data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
penguins = pd.read_csv("data/penguins.csv")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# <img src=https://d2gg9evh47fn9z.cloudfront.net/800px_COLOURBOX38737485.jpg>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
f, axs = plt.subplots(1, 2, figsize=(8, 4))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %%
g = sns.relplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", col="sex")
g.set_axis_labels("Flipper length (mm)", "Bill length (mm)")

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.pairplot(penguins)

# %%
sns.pairplot(data=penguins, hue="species")

# %% [markdown]
# ¿ Visualizing bivariate distributionsm ?

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", kind="kde")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
sns.pairplot(penguins, kind="kde")
